# %% [markdown]
# # Environment check\n\nUse this notebook to validate the local environment.

# %%
import numpy as np\nimport pandas as pd\nimport xarray as xr\nimport geopandas as gpd\nimport cartopy.crs as ccrs\nfrom cmcrameri import cm\n\nprint('Environment ready')\n
